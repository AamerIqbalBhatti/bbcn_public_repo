# %% [markdown]
# # BBCN — one-click reproduction
#
# Press **Runtime → Run all** (or the ▶ button below). No setup needed.
# This clones the repository, installs the dependencies, regenerates the figures and the
# rules appendix from code, and rebuilds the paper. For a full number recompute use
# `python reproduce_all.py --all` (slower).

# %%
import os
if not os.path.exists('reproduce_all.py'):
    # !git clone --depth 1 https://github.com/AamerIqbalBhatti/Systems-Biology-Journal-2026.git repo
    if os.path.exists('repo'):
        os.chdir('repo')
# !pip install -q -r requirements.txt
# !python reproduce_all.py --figures regen
